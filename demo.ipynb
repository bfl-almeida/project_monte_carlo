# %% [markdown]
# # Monte Carlo Option Pricing Demo
#
# This notebook compares Monte Carlo estimates with Black-Scholes analytical prices and explores convergence.

# %%
from option_pricing.analysis import convergence_table
from option_pricing.black_scholes import bs_call_price
from option_pricing.monte_carlo import mc_barrier_option_price

S0, K, T, r, sigma = 100, 100, 1.0, 0.05, 0.2
rows = convergence_table([100, 500, 1_000, 5_000, 10_000, 50_000], S0, K, T, r, sigma)
rows
